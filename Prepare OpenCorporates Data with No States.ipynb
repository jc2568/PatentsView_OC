# %%
import os

### set primary path to csvResults folder and will be applied throughout script. If the
### results range change, modify the a_suff variable to reflect the new range. In general,
### the only variable that needs modified throughout this script is the a_suff variable
### because future iterations should include new ID numbers. Change this variable to
### reflect the new data ranges.

a_path="../"
a_fold="csvResults/"
a_suff="_noStates.csv"

# %%
### import the noState_output to assess how well the new data without city-states matches
### to the OC database

import pandas as pd
import numpy as np
import time
import os
import warnings
warnings.filterwarnings('ignore')

t0=time.time()

a_inpt="noState_output_cleaned.csv"
a_full=os.path.join(a_path,a_fold,a_inpt)

df=pd.read_csv(a_full)

t1=time.time()
total=t1-t0
print("Total time is %4f" % (total/60), "mins")

display(df.info(null_counts=True),df.head())
# Out:
# Total time is 0.001302 mins
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2623 entries, 0 to 2622
# Data columns (total 55 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID                                    2623 non-null   int64
#  1   assignee_id                           2623 non-null   object
#  2   name                                  2034 non-null   object
#  3   company_number                        2034 non-null   object
#  4   jurisdiction_code                     2034 non-null   object
#  5   incorporation_date                    2034 non-null   object
#  6   dissolution_date                      551 non-null    object
#  7   company_type                          2018 non-null   object
#  8   registry_url                          1680 non-null   object
#  9   branch                                897 non-null    object
# ...

# %%
### construct a list of assignees that did not have a matching record to the OC database

assigneesWithNoOCRecord=df[df['name'].isnull()].iloc[:,1:2].reset_index(drop=True)

display(assigneesWithNoOCRecord.info(),assigneesWithNoOCRecord.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589 entries, 0 to 588
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   assignee_id  589 non-null    object
# dtypes: object(1)
# memory usage: 4.7+ KB
# None
#                             assignee_id
# 0  5d5ead2f-1ef7-4db6-a6ce-9cdea523f834
# 1  8a841c57-22b6-4ad0-ad42-16532c3ab4fc
# 2  57ee3f8d-0756-4a84-a29d-adfdaea6e290
# 3  e809c8fa-1ae3-43b4-b504-307c633646e7
# 4  cb6a6b0b-4197-49a2-854d-d2a5e68e5847

# %%
### import the complete dataset to assign states and cities

t0=time.time()

a_inpt="dfMergedFullDataSet.csv"
a_full=os.path.join(a_path,a_fold,a_inpt)

fullData=pd.read_csv(a_full)

t1=time.time()
total=t1-t0
print("Total time is %4f" % (total/60), "mins")

display(fullData.info(null_counts=True),fullData.head())
# Out:
# Total time is 0.006391 mins
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274493 entries, 0 to 274492
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              274493 non-null  int64
#  1   assignee_id     274493 non-null  object
#  2   location_id     274493 non-null  object
#  3   organization    274493 non-null  object
#  4   city            267595 non-null  object
#  5   state           269716 non-null  object
#  6   dateOfFirstPat  274493 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 14.7+ MB
# None
#    ID                           assignee_id  \
# 0   0  fffe9f1f-cb1c-49ab-b00f-6416e3e3a909
# 1   1  fffe8fea-3d13-4016-9429-93653527efa1
# 2   2  fffe4688-bc00-4626-bd89-28921a62f07f
# 3   3  fffe36bb-6dea-4a8b-8bf5-071cf893ceba
# 4   4  fffd9c21-3bb1-4471-b316-d172921e3f83
#
#                             location_id                         organization  \
# ...

# %%
### construct a list of assignees that had no matches to OC

fullData1=fullData.drop_duplicates(subset=['assignee_id'],keep='first')

assigneesWithNoOCRecord1=assigneesWithNoOCRecord.merge(fullData1,on=['assignee_id'],
                                                       how='inner').iloc[:,[1,0,2,3,4,5,6]].sort_values(by=['ID'])

# assigneesWithNoOCRecord1.to_csv("../csvResults/assigneeIDsWithNoStatesNoMatchingOC.csv",index=False)

display(assigneesWithNoOCRecord1.info(),assigneesWithNoOCRecord1.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 589 entries, 232 to 369
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              589 non-null    int64
#  1   assignee_id     589 non-null    object
#  2   location_id     589 non-null    object
#  3   organization    589 non-null    object
#  4   city            566 non-null    object
#  5   state           567 non-null    object
#  6   dateOfFirstPat  589 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 36.8+ KB
# None
#        ID                           assignee_id  \
# 232   802  f8748ef9-f51b-4153-87ad-0f975f94caea
# 469   942  f73af659-8c20-42e9-ac88-1dfdb155f2b9
# 218  1670  f036b99a-e35f-4532-83c9-449a68d26b4c
# 442  1824  eea554c2-8c0a-4d23-8601-320d7c841f98
# 539  2098  ec0b2776-3780-4263-8e61-351e0393b656
#
#                               location_id  \
# 232  f9142a82-09be-11ec-893a-12de62d610b1
# ...

# %%
### import the original 1000 records to calculate the % of assignees with incorporation dates

t0=time.time()

a_inpt="subsetToRerun_1000Records_noStates_Aug_3_2022.csv"
a_full=os.path.join(a_path,a_fold,a_inpt)

df1=pd.read_csv(a_full)

t1=time.time()
total=t1-t0
print("Total time is %4f" % (total/60), "mins")

display(df1.info(null_counts=True),df1.head())
# Out:
# Total time is 0.000067 mins
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   assignee_id     1000 non-null   object
#  1   organization    1000 non-null   object
#  2   dateOfFirstPat  1000 non-null   object
# dtypes: object(3)
# memory usage: 23.6+ KB
# None
#                             assignee_id  \
# 0  5d5ead2f-1ef7-4db6-a6ce-9cdea523f834
# 1  8a841c57-22b6-4ad0-ad42-16532c3ab4fc
# 2  52e38962-9bfc-4082-b0c8-b7ba4ac04d83
# 3  b4f82aab-7c15-4868-8044-81a0ed5d33be
# 4  d62b9811-b171-40ed-a739-7eb54199f188
#
#                              organization dateOfFirstPat
# 0                      Vitric Corporation      7/27/1999
# 1  American Bicycle Manufacturing Company      9/29/1987
# 2                        LendingTree, LLC       5/7/2002
# 3                   Nordstrom Valves, Inc      1/11/2000
# ...

# %%
df2=df

df2.dropna(subset=['incorporation_date'],inplace=True)
df3=df2.iloc[:,1:]

display(df3.info(),df3.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2034 entries, 2 to 2622
# Data columns (total 54 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   assignee_id                           2034 non-null   object
#  1   name                                  2034 non-null   object
#  2   company_number                        2034 non-null   object
#  3   jurisdiction_code                     2034 non-null   object
#  4   incorporation_date                    2034 non-null   object
#  5   dissolution_date                      551 non-null    object
#  6   company_type                          2018 non-null   object
#  7   registry_url                          1680 non-null   object
#  8   branch                                897 non-null    object
#  9   branch_status                         897 non-null    object
#  10  inactive                              1088 non-null   object
# ...

# %%
print("The number of in unique assignee IDs in the input file is:", df3['assignee_id'].nunique())
print("The number of in unique assignee IDs returned in the output file is:", df1['assignee_id'].nunique())
print(f"The percent of returned assignees is: {(df3['assignee_id'].nunique())/df1['assignee_id'].nunique():.2%}")
# Out:
# The number of in unique assignee IDs in the input file is: 411
# The number of in unique assignee IDs returned in the output file is: 1000
# The percent of returned assignees is: 41.10%

# %%
### names were identified to be incorrect by manually screening and the city and state name 
### were removed rather than replaced. This variable will be used to batch remove the names
### in the next cell

t0=time.time()

fullData['organization']=fullData['organization'].str.title()
df3['name']=df3['name'].str.title()

pattern = '|'.join(['Llc','L\.L\.C\.','Inc\.$','Inc$','Ltd','\(.+?\)','Plc','P\.L\.C\.','Pllc','P\.L\.L\.C\.',
                    'Lp\.$','Lp$','Llp$','LP','L\.P\.','LC','L\.C\.','@','\.',','])

t1=time.time()
total=t1-t0
print("Total time is %4f" % (total/60), "mins")
# Out:
# Total time is 0.001686 mins

# %%
### the pattern variable was used in the replace function to remove any matches from the
### organization field

t0=time.time()

fullData['organization']=fullData['organization'].str.lstrip().str.rstrip()

fullData['organization']=fullData['organization'].str.replace(' & ', ' And ')
fullData['organization']=fullData['organization'].str.replace('&', ' And ')
fullData['organization']=fullData['organization'].str.replace(' - |-', ' ')
fullData['organization']=fullData['organization'].str.replace(' (Co\.$|Co$)', ' Company')
fullData['organization']=fullData['organization'].str.replace(' (Corp\.|Corp) ', ' Corporation ')
fullData['organization']=fullData['organization'].str.replace('Mfg', 'Manufacturing')

fullData['organization']=fullData['organization'].str.replace(pattern, '')
fullData['organization']=fullData['organization'].str.lstrip().str.rstrip()

fullData['organization']=fullData['organization'].str.replace(' (Co\.$|Co$)', ' Company')
fullData['organization']=fullData['organization'].str.replace(' (Corp\.$|Corp$) ', ' Corporation ')
fullData['organization']=fullData['organization'].str.replace(' (Corp\.$|Corp$)', ' Corporation')

t1=time.time()
total=t1-t0
print("Total time is %4f" % (total/60), "mins")
# Out:
# Total time is 0.023977 mins

# %%
### the pattern variable was used in the replace function to remove any matches from the
### organization field

t0=time.time()

df3['name']=df3['name'].str.lstrip().str.rstrip()

df3['name']=df3['name'].str.replace(' & ', ' And ')
df3['name']=df3['name'].str.replace('&', ' And ')
df3['name']=df3['name'].str.replace(' - |-', ' ')
df3['name']=df3['name'].str.replace(' (Co\.$|Co$)', ' Company')
df3['name']=df3['name'].str.replace(' (Corp\.|Corp) ', ' Corporation ')
df3['name']=df3['name'].str.replace('Mfg', 'Manufacturing')

df3['name']=df3['name'].str.replace(pattern, '')
df3['name']=df3['name'].str.lstrip().str.rstrip()

df3['name']=df3['name'].str.replace(' (Co\.$|Co$)', ' Company')
df3['name']=df3['name'].str.replace(' (Corp\.$|Corp$) ', ' Corporation ')
df3['name']=df3['name'].str.replace(' (Corp\.$|Corp$)', ' Corporation')

t1=time.time()
total=t1-t0
print("Total time is %4f" % (total/60), "mins")
# Out:
# Total time is 0.000332 mins

# %%
### merge the noState_output file with the dfMergedFullDataSet to attach the PatentsView data

mergeFullWithNoStates=fullData.merge(df3,left_on=['assignee_id','organization'],right_on=['assignee_id','name'],how='inner',
                                    indicator=True)
# mergeFullWithNoStates.to_csv("../csvResults/lookatfullmerge.csv",index=False)

display(mergeFullWithNoStates.info(),mergeFullWithNoStates.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1165 entries, 0 to 1164
# Data columns (total 61 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID                                    1165 non-null   int64
#  1   assignee_id                           1165 non-null   object
#  2   location_id                           1165 non-null   object
#  3   organization                          1165 non-null   object
#  4   city                                  1155 non-null   object
#  5   state                                 1151 non-null   object
#  6   dateOfFirstPat                        1165 non-null   object
#  7   name                                  1165 non-null   object
#  8   company_number                        1165 non-null   object
#  9   jurisdiction_code                     1165 non-null   object
#  10  incorporation_date                    1165 non-null   object
# ...

# %%
mergeFullWithNoStates1=mergeFullWithNoStates.iloc[:,[0,1,2,3,4,5,6,7,9,10,25,26,47,48,51,52,38]]
mergeFullWithNoStates1['state']=mergeFullWithNoStates1['state'].str.title()
mergeFullWithNoStates1['address_city']=mergeFullWithNoStates1['address_city'].str.title()
mergeFullWithNoStates1['address_state']=mergeFullWithNoStates1['address_state'].str.title()
mergeFullWithNoStates1['agent_city']=mergeFullWithNoStates1['agent_city'].str.title()
mergeFullWithNoStates1['agent_state']=mergeFullWithNoStates1['agent_state'].str.title()
mergeFullWithNoStates1['agent_state']=mergeFullWithNoStates1['agent_state'].str.title()

mergeFullWithNoStates1['sub_jurisdiction_code']=mergeFullWithNoStates1['jurisdiction_code'].str[3:].str.title()

mergeFullWithNoStates2=mergeFullWithNoStates1.iloc[:,[0,1,2,3,4,5,6,7,17,9,10,11,12,13,14,15,16]].sort_values(by=['ID'])

display(mergeFullWithNoStates2.info(),mergeFullWithNoStates2.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1165 entries, 0 to 86
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1165 non-null   int64
#  1   assignee_id            1165 non-null   object
#  2   location_id            1165 non-null   object
#  3   organization           1165 non-null   object
#  4   city                   1155 non-null   object
#  5   state                  1151 non-null   object
#  6   dateOfFirstPat         1165 non-null   object
#  7   name                   1165 non-null   object
#  8   sub_jurisdiction_code  1165 non-null   object
#  9   incorporation_date     1165 non-null   object
#  10  alternative_names      87 non-null     object
#  11  previous_names         141 non-null    object
#  12  address_city           523 non-null    object
#  13  address_state          516 non-null    object
# ...

# %%
mergeFullWithNoStates2['assignee_id'].nunique()
# Out:
# 269

# %%
mergeFullWithNoStates2.to_csv("../csvResults/mergedPVOCNoStates.csv",index=False)
